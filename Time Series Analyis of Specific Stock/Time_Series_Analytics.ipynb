# %%
import pandas as pd
import yfinance as yf
import datetime
from datetime import date,timedelta
today=date.today()
d1=today.strftime("%Y-%m-%d")
end_date = d1
d2=date.today()- timedelta(days=720)
d2=d2.strftime("%Y-%m-%d")
start_date=d2

data= yf.download('NVDA',
                  start=start_date,
                  end=end_date,
                  progress=False)
print(data.head())

#Visualizing the stock using line chart
import plotly.express as px
figure =px.line(data,x=data.index,y="Close",title='Time Series Analysis (line chart)')
figure.show()

#Visualizing the stock using candlestick
import plotly.graph_objects as go
figure = go.Figure(data=[go.Candlestick(x = data.index,
                                        open = data["Open"],
                                        high = data["High"],
                                        low = data["Low"],
                                        close = data["Close"])])
figure.update_layout(title="Time Series Analysis (Candlestick chart)",
                     xaxis_rangeslider_visible=False)
figure.show()

#Visualizing using bar chart
figure = px.bar(data, x = data.index,
                y = "Close",
                title = "Time Series Analysis (Bar Plot)" )
figure.show()

#Visualizing the stock for specific dates
figure = px.line(data, x = data.index,
                 y = 'Close',
                 range_x = ['2023-07-01','2023-12-31'],
                 title = "Time Series Analysis (Custom Date Range)")
figure.show()

#Adding slider and buttons for specific time intervals to the candlestick chart
figure = go.Figure(data = [go.Candlestick(x = data.index,
                                        open = data["Open"],
                                        high = data["High"],
                                        low = data["Low"],
                                        close = data["Close"])])
figure.update_layout(title = "Time Series Analysis (Candlestick Chart with Buttons and Slider)")

figure.update_xaxes(
    rangeslider_visible = True,
    rangeselector = dict(
        buttons = list([
            dict(count = 1, label = "1m", step = "month", stepmode = "backward"),
            dict(count = 6, label = "6m", step = "month", stepmode = "backward"),
            dict(count = 1, label = "YTD", step = "year", stepmode = "todate"),
            dict(count = 1, label = "1y", step = "year", stepmode = "backward"),
            dict(step = "all")
        ])
    )
)
figure.show()
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2022-02-09  256.220001  267.250000  253.529999  267.049988  266.682159
# 2022-02-10  259.950012  269.250000  256.000000  258.239990  257.884308
# 2022-02-11  259.160004  261.519989  237.729996  239.490005  239.160156
# 2022-02-14  239.339996  248.750000  237.550003  242.669998  242.335770
# 2022-02-15  249.490005  265.450012  247.839996  264.950012  264.585083
#
#               Volume
# Date
# 2022-02-09  52428200
# 2022-02-10  51320000
# 2022-02-11  60547200
# 2022-02-14  44042400
# 2022-02-15  69986900
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
# ...
